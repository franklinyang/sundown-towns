# %%
import csv
import os

import pandas as pd

# %%
import sys
sys.path.append("../")
from tools import transform_helpers

# %%
data_dir = os.path.join(os.path.abspath(os.path.dirname('.')), '../data')

# %%
police_killings_data = pd.read_csv(os.path.join(data_dir, 'outputs/police_killings_county.csv'))
sundown_towns_county = pd.read_csv(os.path.join(data_dir, 'outputs/county_sundown_counts.csv'))

# %%
police_killings_data.merge(sundown_towns_county, on='county')
# Out:
#     Unnamed: 0  Unnamed: 0.1              City  \
# 0            1             1           Anaheim
# 1           41            41            Irvine
# 2           85            85         Santa Ana
# 3            4             4           Atlanta
# 4            7             7       Bakersfield
# 5           10            10        Birmingham
# 6           12            12           Buffalo
# 7           13            13          Chandler
# 8           56            56              Mesa
# 9           71            71           Phoenix
# 10          86            86        Scottsdale
# 11          16            16           Chicago
# 12          17            17       Chula Vista
# 13          82            82         San Diego
# 14          18            18        Cincinnati
# 15          19            19         Cleveland
# 16          20            20  Colorado Springs
# 17          21            21          Columbus
# 18          23            23            Dallas
# ...
